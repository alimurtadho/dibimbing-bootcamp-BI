# %% [markdown]
# ini adalah teks

# %% [markdown]
# ini juga adalah teks

# %%
print('hello world')
# Out:
# hello world

# %% [markdown]
# # Tipe data

# %%
# integer: bil bulat
# type(x) <- x adalah data

type(1)
# Out:
# int

# %%
# float: bilangan desimal

type(3.14)
# Out:
# float

# %%
# complex:

type(3j)
# Out:
# complex

# %%
# boolean
# hanya memiliki 2 nilai True / False

type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %%
is_ganteng = True

# %%
# string(str) / teks
# teks pada python harus diapit oleh tanda kutip

"aku suka main bola"
# Out:
# 'aku suka main bola'

# %%
type("Rizki")
# Out:
# str

# %%
"Rizki" <- string teks

Rizki <- variable
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-293140679479> in <cell line: 1>()
# ----> 1 Rizki
#
# NameError: name 'Rizki' is not defined

# %%
# break 3 menit (adzan)

# %%
'Rizki'
# Out:
# 'Rizki'

# %%
"Rizki"
# Out:
# 'Rizki'

# %%
# gunakanlah kutip secara konsisten

'Rizki'
# Out:
# 'Rizki'

# %%
"Jum'at"
# Out:
# "Jum'at"

# %%
# List: daftar
# tipe data yang dapat menyimpan multiple nilai
# ciri khas list adalah setiap nilainya diapit oleh tanda [ ]
# dan setiap nilai dipisahkan oleh koma

nama_buah = ['Jeruk' ,'Mangga', 'Apel']

# %%
nama_buah
# Out:
# ['Jeruk', 'Mangga', 'Apel']

# %%
type(nama_buah)
# Out:
# list

# %%
# tuple
# mirip dengan list hanya bedanya adalah diapit oleh ( )

nama_kota = ('Garut','Tasik','Bandung','Malang')

# %%
type(nama_kota)
# Out:
# tuple

# %%
# Set : himpunan
# mampu menyimpan multiple nilai
# memenuhi sifat himpunan
# diapit oleh kurung kurawal
# anggotanya tunggal

him_nama = {'Rizki','Puja','Devi','Rizki'}

# %%
him_nama
# Out:
# {'Devi', 'Puja', 'Rizki'}

# %%
type(him_nama)
# Out:
# set

# %%
# dictionary
# kata : arti
# key : value
# key value pair

orang = {
    'nama':'Rizki',
    'alamat':'Cicaheum',
    'univ':'ITB'
    }

# %%
orang['alamat']
# Out:
# 'Cicaheum'

# %% [markdown]
# ---

# %% [markdown]
# # Variable

# %%
# wadah untuk menyimpan nilai

nama = 'Rizki'
# nama ada variable, sedangkan nilai dari nama adalah 'Rizki'

# 1. nama variabel tidak boleh berupa angka
# 2. nama variabel tidak boleh diawali dengan angka (contoh: 1teman (salah))
# 3. nama variabel tidak boleh mengandung spasi contoh: nama saya xxxxx, nama_saya, namaSaya

# cara memasukkan nilai ke dalam variabel adalah dengan menggunakan =
role = 'Data Scientist'

usia = 22

# %% [markdown]
# # Operasi Dasar

# %%
# operasi yang berlaku untuk numeric variable (int, float)

a = 10
b = 3

# %%
a + b
# Out:
# 13

# %%
a - b
# Out:
# 7

# %%
a * b
# Out:
# 30

# %%
a / b
# Out:
# 3.3333333333333335

# %%
# pangkat
a ** b
# Out:
# 1000

# %%
# 2 pangkat 3
2 ** 3
# Out:
# 8

# %%
# 2 pangkat 5
2 ** 5
# Out:
# 32

# %%
# pembagian bulat
# // dibaca div
# pembagian yang menghasilkan elemen bulat dari hasil
a // b
# Out:
# 3

# %%
a / b
# Out:
# 3.3333333333333335

# %%
# %
# modulo : sisa hasil bagi

# 10 dibagi 3 hasilnya 3 sisa 1
10 % 3
# Out:
# 1

# %%
# 10 bagi 4 hasil 2, sisa 2
10 % 4
# Out:
# 2

# %%
# 10 bagi 5 hasil 2, sisa 0
10 % 5
# Out:
# 0

# %%
10 % 7
# Out:
# 3

# %%
# absolut
# fungsi -> mendapatkan nilai mutlak
# mempositifkan bilangna negatif

-4
# Out:
# -4

# %%
abs(-4)
# Out:
# 4

# %%
abs(4)
# Out:
# 4

# %%
2 ^ 4
# Out:
# 6

# %% [markdown]
# ---

# %% [markdown]
# # Boolean

# %%
# AND, OR, NOT

# and : semua kondisi harus benar

# syarat mendapatkan bansos
# syarat 1 : tidak mampu (penghasilan di bawah 1 jt per bulan) (is_under_1jt)
# syarat 2 : memiliki tanggungan (is_menanggung)

# %%
# orang_A
is_under_1jt = True
is_menanggung = False

is_under_1jt and is_menanggung
# Out:
# False

# %%
# orang_B
is_under_1jt = False
is_menanggung = True

is_under_1jt and is_menanggung
# Out:
# False

# %%
# orang C
is_under_1jt = False
is_menanggung = False

is_under_1jt and is_menanggung
# Out:
# False

# %%
# orang D
is_under_1jt = True
is_menanggung = True

is_under_1jt and is_menanggung
# Out:
# True

# %%
# kondisi 1 AND kondisi 2 AND kondisi 3 dst

# %% [markdown]
# OR

# %%
True or False
# Out:
# True

# %%
False or True
# Out:
# True

# %%
True or True
# Out:
# True

# %%
False or False
# Out:
# False

# %%
# NOT (negasi/kebalikan)

not True
# Out:
# False

# %%
not False
# Out:
# True

# %% [markdown]
# # Perbandingan / Comparison

# %%
# <, <=, >, >=, ==, !=

# %%
4 < 3
# Out:
# False

# %%
4 > 3
# Out:
# True

# %%
4 < 4
# Out:
# False

# %%
# < dengan <= ?

# %%
3 == 5
# Out:
# False

# %%
3 == 3
# Out:
# True

# %%
3 != 5
# Out:
# True

# %%
angka_a = 9
angka_b = 40

# %%
angka_a == angka_b
# Out:
# False

# %%
angka_a != angka_b
# Out:
# True

# %%
# LIST

# %%
X = [5,3,5,6,2,5,7,8,7]

# %%
X[3]
# Out:
# 6

# %%
X[6]
# Out:
# 6

# %%
X[7]
# Out:
# 8

# %%
# slicing
# X[start:finish]
# mengambil elemen dari indeks start sampai finish - 1
X[5:9]
# Out:
# [4, 6, 8, 4]

# %%
# in (untuk menguji apakah ada elemen di suatu list)

3 in [1,2,3,4,5]
# Out:
# True

# %%
3 not in [1,2,3,4,5]
# Out:
# False

# %%
# +

A = [1,2,3,4,5,6]
B = [6,7,8,9,10]

# %%
A + B
# Out:
# [1, 2, 3, 4, 5, 6, 6, 7, 8, 9, 10]

# %%
# *
A * 2
# Out:
# [1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6]

# %%
# mengetahui panjang list, banyak nya data
len(A)
# Out:
# 6

# %%
min(A)
# Out:
# 1

# %%
max(B)
# Out:
# 10

# %%
B = [1,1,1,2,2,3,4,5,6]

B.count(1)
# Out:
# 3

# %%
# append, menambahkan elemen di belakang
B.append(100)

# %%
B
# Out:
# [1, 1, 1, 2, 2, 3, 4, 5, 6, 100]

# %%
# pop menghapus elemen di indeks i
# menampilkan bilangan yang dihapus
B.pop(4)
# Out:
# 2

# %%
B
# Out:
# [1, 1, 1, 2, 3, 4, 5, 6, 100]

# %%
# reverse, membalikkan
B.reverse()

# %%
B
# Out:
# [100, 6, 5, 4, 3, 2, 1, 1, 1]

# %%
# clear, menghapus semua nilai
B.clear()

# %%
B
# Out:
# []

# %%
# bedanya tuple dan list
# tuple tidak memperbolehkan operasi yang mengganggu struktur yang sudah ada

A_list = [1,2,3,4,5,6]
A_tuple = (1,2,3,4,5,6)

# %%
A_list.append(10)

# %%
A_list
# Out:
# [1, 2, 3, 4, 5, 6, 10]

# %%
A_tuple.append(10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-106-b1b3724e72d3> in <cell line: 1>()
# ----> 1 A_tuple.append(10)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
A_tuple[5]
# Out:
# 6

# %%
A_tuple.pop(3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-108-7b0292d63287> in <cell line: 1>()
# ----> 1 A_tuple.pop(3)
#
# AttributeError: 'tuple' object has no attribute 'pop'

# %%
# string

nama_depan = 'Rizki'
nama_belakang = 'Kurniawan'

# %%
# + penyambungan
nama_depan + nama_belakang
# Out:
# 'RizkiKurniawan'

# %%
nama_depan * 3
# Out:
# 'RizkiRizkiRizki'

# %%
nama_depan.lower()
# Out:
# 'rizki'

# %%
nama_depan.upper()
# Out:
# 'RIZKI'

# %%
email = 'email_saya@gmail.com'

# %%
email.split('@')
# Out:
# ['email_saya', 'gmail.com']

# %%
# string mengenal indexing

# %%
nama_depan
# Out:
# 'Rizki'

# %%
nama_depan[3]
# Out:
# 'k'

# %% [markdown]
# # Operasi pada SET

# %%
him_A = {'Jeruk','Apel','Mangga','Lemon'}
him_B = {'Jeruk','Lemon','Semangka','Jambu'}

# %%
# update

him_A.update(him_B)

# %%
him_A
# Out:
# {'Apel', 'Jambu', 'Jeruk', 'Lemon', 'Mangga', 'Semangka'}

# %%
him_A = {'Jeruk','Apel','Mangga','Lemon'}
him_B = {'Jeruk','Lemon','Semangka','Jambu'}

# %%
him_A
# Out:
# {'Apel', 'Jeruk', 'Lemon', 'Mangga'}

# %%
him_A.remove('Jeruk')

# %%
him_A
# Out:
# {'Apel', 'Lemon', 'Mangga'}

# %%
# Gabungan / Union

him_A.union(him_B)
# Out:
# {'Apel', 'Jambu', 'Jeruk', 'Lemon', 'Mangga', 'Semangka'}

# %%
him_A
# Out:
# {'Apel', 'Lemon', 'Mangga'}

# %%
him_B
# Out:
# {'Jambu', 'Jeruk', 'Lemon', 'Semangka'}

# %%
# Irisan / intersection
him_A.intersection(him_B)
# Out:
# {'Lemon'}

# %%
# difference, elemen yang ada di A tapi tidak ada di B
him_A - him_B
# Out:
# {'Apel', 'Mangga'}

# %%
him_B - him_A
# Out:
# {'Jambu', 'Jeruk', 'Semangka'}

# %%
# subhimpunan
# apakah himpunan A termuat oleh himpunan B

A = {1,2,3}
B = {1,2,3,4,5,6}

A.issubset(B)
# Out:
# True

# %%
A[2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-137-d90411c862f7> in <cell line: 1>()
# ----> 1 A[2]
#
# TypeError: 'set' object is not subscriptable

# %% [markdown]
# # Operasi yang berlaku di dictionary

# %%
teman = {
    'nama':'eka',
    'alamat':'padasuka',
    'usia':32
}

# %%
teman['nama']
# Out:
# 'eka'

# %%
teman
# Out:
# {'nama': 'eka', 'alamat': 'padasuka', 'usia': 32}

# %%
teman.keys()
# Out:
# dict_keys(['nama', 'alamat', 'usia'])

# %%
teman.values()
# Out:
# dict_values(['eka', 'padasuka', 32])

# %%
# menambahkan pasangan key dan value yang baru,
# cukup assign key yang baru tersebut

teman['hp']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-145-6add5a3583e1> in <cell line: 4>()
#       2 # cukup assign key yang baru tersebut
#       3
# ----> 4 teman['hp']
#
# KeyError: 'hp'

# %%
teman['hp'] = 6280989999

# %%
teman
# Out:
# {'nama': 'eka', 'alamat': 'padasuka', 'usia': 32, 'hp': 6280989999}
