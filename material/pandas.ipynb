# %%
import pandas as pd
# import os
# import sys

# def c

# %%
# sys.path.insert(0, os.path.abspath('../dataset/Sample Superstore.xls'))

# %%
#import excel
read_excel = pd.read_excel("/Users/newuser/ali/project/kampus merdeka/repo_dibimbing/dataset/Untitled spreadsheet.xlsx")

# %%
read_excel
# Out:
#            Date       Price        Open        High         Low     Volume  \
# 0    2017-10-02  252.320007  251.490005  252.320007  251.289993   59023000
# 1    2017-10-03  252.860001  252.320007  252.889999  252.229996   66810200
# 2    2017-10-04  253.160004  252.690002  253.440002  252.559998   55953600
# 3    2017-10-05  254.660004  253.539993  254.679993  253.199997   63522800
# 4    2017-10-06  254.369995  254.149994  254.699997  253.850006   80646000
# ...         ...         ...         ...         ...         ...        ...
# 1254 2022-09-26  364.309998  366.410004  370.209991  363.029999   92581200
# 1255 2022-09-27  363.380005  368.019989  370.399994  360.869995  108294100
# 1256 2022-09-28  370.529999  364.380005  372.299988  362.600006  110802200
# 1257 2022-09-29  362.790009  366.809998  367.109985  359.700012  112952300
# 1258 2022-09-30  357.179993  361.799988  365.910004  357.040009  153711200
#
#         Change
# 0     0.004300
# 1     0.002140
# 2     0.001186
# ...

# %%
#import csv
read_file = pd.read_csv ('/Users/newuser/ali/project/kampus merdeka/repo_dibimbing/dataset/Data latihan sql/Sample - Store - Orders.csv')

# %%
# print(read_file)
read_file
# Out:
#             Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0     CA-2016-152156  11/08/2016  11/11/2016    Second Class    CG-12520
# 1     CA-2016-152156  11/08/2016  11/11/2016    Second Class    CG-12520
# 2     CA-2016-138688  06/12/2016  06/16/2016    Second Class    DV-13045
# 3     US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4     US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# ...              ...         ...         ...             ...         ...
# 9989  CA-2014-110422  01/21/2014  01/23/2014    Second Class    TB-21400
# 9990  CA-2017-121258  02/26/2017  03/03/2017  Standard Class    DB-13060
# 9991  CA-2017-121258  02/26/2017  03/03/2017  Standard Class    DB-13060
# 9992  CA-2017-121258  02/26/2017  03/03/2017  Standard Class    DB-13060
# 9993  CA-2017-119914  05/04/2017  05/09/2017    Second Class    CC-12220
#
#          Customer Name    Segment        Country             City       State  \
# ...

# %%
data = read_file

# %%
#show information dataset
data.info() #
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       9994 non-null   object
#  1   Order Date     9994 non-null   object
#  2   Ship Date      9994 non-null   object
#  3   Ship Mode      9994 non-null   object
#  4   Customer ID    9994 non-null   object
#  5   Customer Name  9994 non-null   object
#  6   Segment        9994 non-null   object
#  7   Country        9994 non-null   object
#  8   City           9994 non-null   object
#  9   State          9994 non-null   object
#  10  Postal Code    9994 non-null   int64
#  11  Region         9994 non-null   object
#  12  Product ID     9994 non-null   object
#  13  Category       9994 non-null   object
#  14  Sub-Category   9994 non-null   object
#  15  Product Name   9994 non-null   object
#  16  Sales          9994 non-null   float64
# ...

# %%
#show data 5 teratas
data.head(10)
# Out:
#          Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0  CA-2016-152156  11/08/2016  11/11/2016    Second Class    CG-12520
# 1  CA-2016-152156  11/08/2016  11/11/2016    Second Class    CG-12520
# 2  CA-2016-138688  06/12/2016  06/16/2016    Second Class    DV-13045
# 3  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 5  CA-2014-115812  06/09/2014  06/14/2014  Standard Class    BH-11710
# 6  CA-2014-115812  06/09/2014  06/14/2014  Standard Class    BH-11710
# 7  CA-2014-115812  06/09/2014  06/14/2014  Standard Class    BH-11710
# 8  CA-2014-115812  06/09/2014  06/14/2014  Standard Class    BH-11710
# 9  CA-2014-115812  06/09/2014  06/14/2014  Standard Class    BH-11710
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# ...

# %%
#show data desc 
data.tail(15)
# Out:
#             Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 9979  US-2016-103674  12/06/2016  12/10/2016  Standard Class    AP-10720
# 9980  US-2015-151435  09/06/2015  09/09/2015    Second Class    SW-20455
# 9981  CA-2017-163566  08/03/2017  08/06/2017     First Class    TB-21055
# 9982  US-2016-157728  09/22/2016  09/28/2016  Standard Class    RC-19960
# 9983  US-2016-157728  09/22/2016  09/28/2016  Standard Class    RC-19960
# 9984  CA-2015-100251  05/17/2015  05/23/2015  Standard Class    DV-13465
# 9985  CA-2015-100251  05/17/2015  05/23/2015  Standard Class    DV-13465
# 9986  CA-2016-125794  09/29/2016  10/03/2016  Standard Class    ML-17410
# 9987  CA-2017-163629  11/17/2017  11/21/2017  Standard Class    RA-19885
# 9988  CA-2017-163629  11/17/2017  11/21/2017  Standard Class    RA-19885
# 9989  CA-2014-110422  01/21/2014  01/23/2014    Second Class    TB-21400
# 9990  CA-2017-121258  02/26/2017  03/03/2017  Standard Class    DB-13060
# ...

# %%
#calculate data row and coloumn
data.shape
# Out:
# (9994, 20)

# %%
data["Sales"].max()
# Out:
# 22638.48

# %%
#show statistical number data type
data.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
#statistical serderna all colloumn
data.describe(include = "all")
# Out:
#               Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# count             9994        9994        9994            9994        9994
# unique            5009        1237        1334               4         793
# top     CA-2017-100111  09/05/2016  12/16/2015  Standard Class    WB-21850
# freq                14          38          35            5968          37
# mean               NaN         NaN         NaN             NaN         NaN
# std                NaN         NaN         NaN             NaN         NaN
# min                NaN         NaN         NaN             NaN         NaN
# 25%                NaN         NaN         NaN             NaN         NaN
# 50%                NaN         NaN         NaN             NaN         NaN
# 75%                NaN         NaN         NaN             NaN         NaN
# max                NaN         NaN         NaN             NaN         NaN
#
# ...

# %%
#show data uninque / distinct
data["Customer Name"].unique()
# Out:
# array(['Claire Gute', 'Darrin Van Huff', "Sean O'Donnell",
#        'Brosina Hoffman', 'Andrew Allen', 'Irene Maddox', 'Harold Pawlan',
#        'Pete Kriz', 'Alejandro Grove', 'Zuschuss Donatelli', 'Ken Black',
#        'Sandra Flanagan', 'Emily Burns', 'Eric Hoffmann',
#        'Tracy Blumstein', 'Matt Abelman', 'Gene Hale', 'Steve Nguyen',
#        'Linda Cazamias', 'Ruben Ausman', 'Erin Smith', 'Odella Nelson',
#        "Patrick O'Donnell", 'Lena Hernandez', 'Darren Powers',
#        'Janet Molinari', 'Ted Butterfield', 'Kunst Miller',
#        'Paul Stevenson', 'Brendan Sweed', 'Karen Daniels',
#        'Henry MacAllister', 'Joel Eaton', 'Ken Brennan',
#        'Stewart Carmichael', 'Duane Noonan', 'Julie Creighton',
#        'Christopher Schild', 'Paul Gonzalez', 'Gary Mitchum', 'Jim Sink',
#        'Karl Braun', 'Roger Barcio', 'Parhena Norris', 'Katherine Ducich',
#        'Elpida Rittenbach', 'Rick Bensley', 'Gary Zandusky',
# ...

# %%
# # check missing value
# data = pd.DataFrame(data)

# using isnull() function
data.isnull()
# Out:
#       Order ID  Order Date  Ship Date  Ship Mode  Customer ID  Customer Name  \
# 0        False       False      False      False        False          False
# 1        False       False      False      False        False          False
# 2        False       False      False      False        False          False
# 3        False       False      False      False        False          False
# 4        False       False      False      False        False          False
# ...        ...         ...        ...        ...          ...            ...
# 9989     False       False      False      False        False          False
# 9990     False       False      False      False        False          False
# 9991     False       False      False      False        False          False
# 9992     False       False      False      False        False          False
# 9993     False       False      False      False        False          False
#
# ...

# %%
#check data insull with resume jumlah
data.isnull().sum()
# Out:
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
#check data duplicat
data.duplicated().sum()
# Out:
# 1

# %%
#show data is duplicate
data[data.duplicated(keep=False)]
# Out:
#             Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 3405  US-2014-150119  04/23/2014  04/27/2014  Standard Class    LB-16795
# 3406  US-2014-150119  04/23/2014  04/27/2014  Standard Class    LB-16795
#
#        Customer Name      Segment        Country      City State  Postal Code  \
# 3405  Laurel Beltran  Home Office  United States  Columbus  Ohio        43229
# 3406  Laurel Beltran  Home Office  United States  Columbus  Ohio        43229
#
#      Region       Product ID   Category Sub-Category  \
# 3405   East  FUR-CH-10002965  Furniture       Chairs
# 3406   East  FUR-CH-10002965  Furniture       Chairs
#
#                                            Product Name    Sales  Quantity  \
# 3405  Global Leather Highback Executive Chair with P...  281.372         2
# 3406  Global Leather Highback Executive Chair with P...  281.372         2
#
#       Discount   Profit
# 3405       0.3 -12.0588
# 3406       0.3 -12.0588

# %%
#select data with name coloumns
selected_data= data[["Order ID","Ship Mode","Region"]]

# %%
selected_data.duplicated().sum()
# Out:
# 4985

# %%
#select data with slicing
selectd_slice = data.iloc[:, 2:9]

# %%
#filtering
filter_ship_mode = selectd_slice["Ship Mode"] = "Second Class"

# %%
filter_ship_mode
# Out:
# 'Second Class'

# %%
# removing null values to avoid errors
data.dropna(inplace = True)

# %%
data.isnull().sum()
# Out:
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
#check data
data = data.loc[:,~data.columns.duplicated()]

# %%
data.drop_duplicates(subset=['Order ID'], inplace=True)

# %%
data.duplicated().sum()
# Out:
# 0

# %%
#pandas sql
from pandasql import sqldf

# %%
q="""SELECT DISTINCT Category FROM data;"""
pysqldf = lambda q: sqldf(q, globals())
a_df = pysqldf(q)
print(a_df)
# Out:
#           Category
# 0        Furniture
# 1  Office Supplies
# 2       Technology

# %%
query = """
select *
from data

order by 'Order ID' asc
limit 5
"""
pysqldf = lambda q: sqldf(query, globals())
df = pysqldf(query)
df
# Out:
#          Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0  CA-2016-152156  11/08/2016  11/11/2016    Second Class    CG-12520
# 1  CA-2016-138688  06/12/2016  06/16/2016    Second Class    DV-13045
# 2  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 3  CA-2014-115812  06/09/2014  06/14/2014  Standard Class    BH-11710
# 4  CA-2017-114412  04/15/2017  04/20/2017  Standard Class    AA-10480
#
#      Customer Name    Segment        Country             City           State  \
# 0      Claire Gute   Consumer  United States        Henderson        Kentucky
# 1  Darrin Van Huff  Corporate  United States      Los Angeles      California
# 2   Sean O'Donnell   Consumer  United States  Fort Lauderdale         Florida
# 3  Brosina Hoffman   Consumer  United States      Los Angeles      California
# 4     Andrew Allen   Consumer  United States          Concord  North Carolina
#
#    Postal Code Region       Product ID         Category Sub-Category  \
# ...

# %%
data.columns = map(str.lower, data.columns)
data.columns = data.columns.str.replace(' ', '_')

# %%
data.columns = data.columns.str.replace('-', '_')

# %%
read_file.duplicated().sum()
# Out:
# 1

# %%
# initialize list of lists
data_frame = [['tom', 10], ['nick', 15], ['juli', 14]]
 
# Create the pandas DataFrame
df_contoh = pd.DataFrame(data_frame, columns=['Name', 'Age'])
 
# print dataframe.
print(df_contoh)
# Out:
#    Name  Age
# 0   tom   10
# 1  nick   15
# 2  juli   14

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5009 entries, 0 to 9993
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_id       5009 non-null   object
#  1   order_date     5009 non-null   object
#  2   ship_date      5009 non-null   object
#  3   ship_mode      5009 non-null   object
#  4   customer_id    5009 non-null   object
#  5   customer_name  5009 non-null   object
#  6   segment        5009 non-null   object
#  7   country        5009 non-null   object
#  8   city           5009 non-null   object
#  9   state          5009 non-null   object
#  10  postal_code    5009 non-null   int64
#  11  region         5009 non-null   object
#  12  product_id     5009 non-null   object
#  13  category       5009 non-null   object
#  14  sub_category   5009 non-null   object
#  15  product_name   5009 non-null   object
#  16  sales          5009 non-null   float64
# ...

# %%
print(f"Distinct entries: {len(data.groupby(['Order Date', 'Sales']))}")
# Out:
# Distinct entries: 9601

# %%
data['year'] = data['Order Date'].dt.year
print(data['year'])
# Out:
# 0        2018
# 1        2018
# 2        2018
# 3        2017
# 4        2017
#          ...
# 12415    2019
# 12416    2019
# 12417    2019
# 12418    2019
# 12419    2016
# Name: year, Length: 12409, dtype: int64

# %%
data['year'].value_counts()
# Out:
# 2019    4273
# 2018    3175
# 2017    2520
# 2016    2441
# Name: year, dtype: int64

# %%
# !pip3 install sqlalchemy
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# ...
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621

# %%
# !pip3 install psycopg2
# !pip3 install pycopg2-binary

# %%
from sqlalchemy import create_engine
from sqlalchemy.types import Integer, Text, String, DateTime

# %%
conection=create_engine('postgresql://postgres:qweasd@localhost:5432/exam_sql')

# %%
data = pd.read_sql('select * from users', con=conection)
print(data)
# Out:
#       id        name  gender  age
# 0      1       Giana       1   17
# 1      2       Diann       1   22
# 2      3   Antonella       1   22
# 3      4        Jodi       0   29
# 4      5      Fredra       1   54
# ..   ...         ...     ...  ...
# 320  321     Chandra       1   31
# 321  322      Dieter       0   15
# 322  323       Belia       1   35
# 323  324  Georgianna       1   48
# 324  325        Nita       1   40
#
# [325 rows x 4 columns]
